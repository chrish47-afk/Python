# %%
#Author: Christian Hernandez
#Date: 01/04/2024
#Description: Converting Distiller SR PDFs conventional names to Ref IDs. This will facilitate NID
#creation in the future. ALso for vetting purposes.

#%pip install openpyxl PyPDF2

# %%
# Removes PDF Duplicates

import os
import hashlib

def calculate_file_hash(file_path):
    """
    Calculate the MD5 hash of a file's content.
    """
    hash_md5 = hashlib.md5()
    with open(file_path, "rb") as file:
        while True:
            data = file.read(8192)
            if not data:
                break
            hash_md5.update(data)
    return hash_md5.hexdigest()

def find_duplicate_pdfs(directory):
    """
    Find and remove duplicate PDF files in a directory.
    """
    file_hash_dict = {}
    duplicates = []

    # Traverse the directory and calculate hashes
    for root, dirs, files in os.walk(directory):
        for filename in files:
            if filename.lower().endswith(".pdf"):
                file_path = os.path.join(root, filename)
                file_hash = calculate_file_hash(file_path)

                # Check if the same hash already exists
                if file_hash in file_hash_dict:
                    duplicates.append((file_path, file_hash_dict[file_hash]))
                else:
                    file_hash_dict[file_hash] = file_path

    return duplicates

def remove_duplicate_pdfs(directory):
    """
    Remove duplicate PDF files from a directory.
    """
    duplicates = find_duplicate_pdfs(directory)

    for duplicate in duplicates:
        file_path, original_path = duplicate
        os.remove(file_path)
        print(f"Removed duplicate: {file_path}")

if __name__ == "__main__":
    directory = "/snfs1/Project/birds/team_documents/maternal_morbidity/high_FPG_SR/Extraction/NIDs/PDFs/"
    remove_duplicate_pdfs(directory)
print("Done")
# Out:
# Done

# %%
### Unstacking the vertical stacked characters in Column B

import pandas as pd

# Read the Excel file into a DataFrame
df = pd.read_excel("/snfs1/Project/birds/team_documents/maternal_morbidity/high_FPG_SR/Extraction/NIDs/bench.xlsx")

# Initialize an empty DataFrame to store the separated rows
new_rows = []

# Iterate through each row in the original DataFrame
for _, row in df.iterrows():
    # Split the vertically stacked values in Column B by newline character '\n'
    stacked_values = row["Column B"].split("\n")

    # Create a new row for each separated value, with the same value in Column A
    for value in stacked_values:
        new_row = {"Column A": row["Column A"], "Column B": value.strip()}
        new_rows.append(new_row)

# Create a new DataFrame from the list of separated rows
new_df = pd.DataFrame(new_rows)

# Save the separated data to a new Excel file
new_df.to_excel("/snfs1/Project/birds/team_documents/maternal_morbidity/high_FPG_SR/Extraction/NIDs/bench.xlsx", index=False)
print("Done")

# Rename the RefID column 'Column A'
# Rename the Attachment column "Column B"
# Out:
# Done

# %%
# Deleting .pdf, .docx, () & , from Column B characters.

import pandas as pd

# Read the Excel file into a DataFrame
df = pd.read_excel("/snfs1/Project/birds/team_documents/maternal_morbidity/high_FPG_SR/Extraction/NIDs/bench.xlsx")

# Remove '.pdf' and '.docx' from values in Column B
df["Column B"] = df["Column B"].str.replace(".pdf", "").str.replace(".docx", "").str.replace(",", "").str.replace("?", "")

# Save the cleaned data to a new Excel file
df.to_excel("/snfs1/Project/birds/team_documents/maternal_morbidity/high_FPG_SR/Extraction/NIDs/bench.xlsx", index=False)
# Out:
# /tmp/ipykernel_1435532/2309259458.py:9: FutureWarning: The default value of regex will change from True to False in a future version.
#   df["Column B"] = df["Column B"].str.replace(".pdf", "").str.replace(".docx", "").str.replace(",", "").str.replace("?", "")
# /tmp/ipykernel_1435532/2309259458.py:9: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df["Column B"] = df["Column B"].str.replace(".pdf", "").str.replace(".docx", "").str.replace(",", "").str.replace("?", "")

# %%
import os
import openpyxl

# Load the Excel file
excel_file = "/snfs1/Project/birds/team_documents/maternal_morbidity/high_FPG_SR/Extraction/NIDs/bench.xlsx"  # Replace with your Excel file name
workbook = openpyxl.load_workbook(excel_file)
worksheet = workbook.active

# Create a dictionary to map old names to new names
name_mapping = {}
for row in worksheet.iter_rows(min_row=2, values_only=True):
    new_name, old_name = row
    if old_name and new_name:
        name_mapping[old_name] = new_name

# Directory where the PDF files are located
pdf_directory = "/snfs1/Project/birds/team_documents/maternal_morbidity/high_FPG_SR/Extraction/NIDs/PDFs/"  # Replace with the path to your PDF files directory

# Iterate through the PDF files in the directory
for pdf_file in os.listdir(pdf_directory):
    if pdf_file.endswith(".pdf"):
        old_name = pdf_file[:-4]  # Remove ".pdf" extension
        if old_name in name_mapping:
            new_name = name_mapping[old_name]
            old_pdf_path = os.path.join(pdf_directory, pdf_file)
            new_pdf_path = os.path.join(pdf_directory, f"{new_name}.pdf")
            
            # Rename the PDF file
            os.rename(old_pdf_path, new_pdf_path)
            print(f"Renamed '{old_name}.pdf' to '{new_name}.pdf'")

# Close the Excel file
workbook.close()
print("Done")
# Out:
# Renamed '17392.pdf' to '17392.pdf'
# Renamed 'bmjopen-2018-025084.PMC6500205.pdf' to '20885.pdf'
# Renamed '26883.pdf' to '26883.pdf'
# Renamed '35914203.pdf' to '35914203.pdf'
# Renamed '24239Yong-High early pregnancy serum 25-hydroxy vit.pdf' to '24239.pdf'
# Renamed '18810Satodiya-Comparison of One-Step Versus Two-Ste.pdf' to '18810.pdf'
# Renamed '15634Alsaedi-Prevalence and risk factors of gestati.pdf' to '15634.pdf'
# Renamed 'Glasser et al. 2011.pdf' to '35914562.pdf'
# Renamed 'Yin et al. 2022.pdf' to '23072.pdf'
# Renamed 'fendo-12-644770.pdf' to '25264.pdf'
# Renamed '24139Nigatu-Prevalence of Gestational Diabetes Mell.pdf' to '24139.pdf'
# Renamed 'JFMPC-11-4545.PMC9638613.pdf' to '22886.pdf'
# Renamed 'je-32-069.pdf' to '26126.pdf'
# Renamed '18257.pdf' to '18257.pdf'
# Renamed '16322Dong-Chocolate consumption and risk of gestati.pdf' to '16322.pdf'
# Renamed 'Lee et al. 1996.pdf' to '1161.pdf'
# Renamed '17606.pdf' to '17606.pdf'
# Renamed '618.PMC3579359.pdf' to '35914593.pdf'
# Renamed '24639Nwali-Universal versus selective screening for.pdf' to '24639.pdf'
# Renamed '16720Arora-Phenotypic and genotypic differences bet.pdf' to '16720.pdf'
# Renamed 'ijerph-17-01221.pdf' to '15582.pdf'
# Renamed 'Soomro et al. 2019.pdf' to '16986.pdf'
# Renamed '35914490.pdf' to '35914490.pdf'
# Renamed '592_2022_Article_2000.pdf' to '22893.pdf'
# Renamed 'Di Cianni et al. 1997.pdf' to '1032.pdf'
# Renamed '12889_2022_Article_12663.pdf' to '24213.pdf'
# Renamed '40842_2016_Article_28.pdf' to '20001.pdf'
# Renamed 'JFCM-13-55.PMC3410064.pdf' to '9981.pdf'
# Renamed '23788Diao-Bayes Conditional Probability-Based Causa.pdf' to '23788.pdf'
# Renamed 'Garmendia et al. 2018.pdf' to '17467.pdf'
# Renamed '21494772-Sullivan-Atlantic Diabetes in Pregnan.pdf' to '21494772.pdf'
# Renamed 'Lindsay et al. 1989.pdf' to '2529.pdf'
# Renamed 'Wan et al. 2011.pdf' to '12549.pdf'
# Renamed 'Yang et al. 2009.pdf' to '19929987.pdf'
# Renamed 'Prevalence of gestational diabetes with a 2-step strategy and cutoff values from the 1979 National Diabetes Data Group. Are we applying the best strategy for our patients.pdf' to '23491.pdf'
# Renamed '35914442.pdf' to '35914442.pdf'
# Renamed 'Rodriguez et al. 1995.pdf' to '3810.pdf'
# Renamed '6730Huy-Prevalence Trend and Determining Factors.pdf' to '6730.pdf'
# Renamed '21112.pdf' to '21112.pdf'
# Renamed '14412Pagotto-[Trends in the frequency of obesity an.pdf' to '14412.pdf'
# Renamed '12933_2016_Article_338.pdf' to '20176.pdf'
# Renamed '15795.pdf' to '15795.pdf'
# Renamed 'Akhter et al. 1996.pdf' to '1274.pdf'
# Renamed 'fcdhc-03-854332.pdf' to '22259.pdf'
# Renamed '22478.pdf' to '22478.pdf'
# Renamed '15524.pdf' to '15524.pdf'
# Renamed '35914503.pdf' to '35914503.pdf'
# Renamed 'Bianco et al. 1996.pdf' to '1200.pdf'
# Renamed 'Aydin et al. 2019.pdf' to '17193.pdf'
# Renamed 'Senanayake et al. 2006.pdf' to '13104.pdf'
# Renamed '22244Akinyemi-Screening for Gestational Diabetes Me.pdf' to '22244.pdf'
# Renamed '12884_2015_Article_597.pdf' to '14133.pdf'
# Renamed '23757431Avalos-Applying current screening tools for ge.pdf' to '23757431.pdf'
# Renamed 'Ricart et al. 1999.pdf' to '393.pdf'
# Renamed 'Boriboonhirunsarn et al. 2021.pdf' to '27509.pdf'
# Renamed 'BMRI2017-6878263.pdf' to '18948.pdf'
# Renamed '19544.pdf' to '19544.pdf'
# Renamed '18276Laine-Gestational diabetes in primiparous wome.pdf' to '18276.pdf'
# Renamed '35914525.pdf' to '35914525.pdf'
# Renamed 'ijerph-15-02646.pdf' to '17134.pdf'
# Renamed '592_2019_Article_1354.pdf' to '16555.pdf'
# Renamed '41598_2019_Article_43665.pdf' to '16569.pdf'
# Renamed 'Sharma et al. 2018.pdf' to '22128.pdf'
# Renamed '18589.pdf' to '18589.pdf'
# Renamed '14204Bardenheier-Trends in Gestational Diabetes Amo.pdf' to '14204.pdf'
# Renamed '22670Bashir-Incidence of gestational diabetes melli.pdf' to '22670.pdf'
# Renamed '15366.pdf' to '15366.pdf'
# Renamed '22444.pdf' to '22444.pdf'
# Renamed 'S000711452200157Xa.pdf' to '23711.pdf'
# Renamed '24265Valadan-The role of first-trimester HbA1c in t.pdf' to '24265.pdf'
# Renamed 'IJEM-20-491.PMC4911838.pdf' to '19762.pdf'
# Renamed '17375.pdf' to '17375.pdf'
# Renamed 'JDI-11-1651.PMC7610133.pdf' to '20568.pdf'
# Renamed '19564.pdf' to '19564.pdf'
# Renamed 'Chuang et al. 2006.pdf' to '10163.pdf'
# Renamed 'IJCM-44-142.PMC6625265.pdf' to '16332.pdf'
# Renamed 'fnut-09-977195.pdf' to '23068.pdf'
# Renamed 'Ozgu-Erdinc et al. 2019.pdf' to '16966.pdf'
# Renamed '35914510.pdf' to '35914510.pdf'
# Renamed 'Jacobson and Cousins 1989.pdf' to '2454.pdf'
# Renamed 'pmed.1003884.pdf' to '24357.pdf'
# Renamed 'Rono et al. 2019.pdf' to '17279.pdf'
# Renamed '41598_2021_Article_99993.pdf' to '26745.pdf'
# Renamed '19194.pdf' to '19194.pdf'
# Renamed 'Wilkie et al. 2021.pdf' to '26377.pdf'
# Renamed 'Jang et al. 1998.pdf' to '703.pdf'
# Renamed 'Yogev et al. 2010.pdf' to '35914567.pdf'
# Renamed 'Sun et al. 1995.pdf' to '1322.pdf'
# Renamed 'cureus-0013-00000017424.pdf' to '24752.pdf'
# Renamed 'pone.0225978.pdf' to '15871.pdf'
# Renamed 'Nasrat et al. 1988.pdf' to '2595.pdf'
# Renamed 'Martin et al. 1995.pdf' to '1515.pdf'
# Renamed '592_2022_Article_2013.pdf' to '22712.pdf'
# Renamed '21551Holst-Fertility problems and risk of gestation.pdf' to '21551.pdf'
# Renamed 'Liu et al. 2022.pdf' to '27218.pdf'
# Renamed 'ogs-19212.PMC7393761.pdf' to '15055.pdf'
# Renamed 'ijerph-17-03109.pdf' to '15317.pdf'
# Renamed '35914632.pdf' to '35914632.pdf'
# Renamed 'je-31-392.pdf' to '26222.pdf'
# Renamed 'main.PMC10034503.pdf' to '22285.pdf'
# Renamed '8032Kim-Percentage of gestational diabetes mellitu.pdf' to '8032.pdf'
# Renamed '14080.pdf' to '14080.pdf'
# Renamed 'Chaim et al. 2000.pdf' to '251.pdf'
# Renamed '35914499.pdf' to '35914499.pdf'
# Renamed 'NAJMS-5-191.PMC3632022.pdf' to '5882.pdf'
# Renamed 'Ray et al. 1996.pdf' to '1166.pdf'
# Renamed 'Sugaya et al. 2000.pdf' to '175.pdf'
# Renamed '17376.pdf' to '17376.pdf'
# Renamed 'JDR2019-9583927.pdf' to '15780.pdf'
# Renamed '15475.pdf' to '15475.pdf'
# Renamed '15876.pdf' to '15876.pdf'
# Renamed '26854.pdf' to '26854.pdf'
# Renamed 'Schmidt et al. 2000.pdf' to '35914622.pdf'
# Renamed 'Aziz et al. 2014.pdf' to '4833.pdf'
# Renamed '19492.pdf' to '19492.pdf'
# Renamed '24465Kim-Fetal abdominal overgrowth is already pres.pdf' to '24465.pdf'
# Renamed 'bmjdrc-2016-000286.PMC5073586.pdf' to '19335.pdf'
# Renamed 'IJEM-21-184.PMC5240063.pdf' to '19091.pdf'
# Renamed '21015.pdf' to '21015.pdf'
# Renamed '17806.pdf' to '17806.pdf'
# Renamed '15245Masalin-Impact of smoking on gestational diabe.pdf' to '15245.pdf'
# Renamed 'Li et al. 2017.pdf' to '35914588.pdf'
# Renamed 'nutrients-11-00405.pdf' to '20976.pdf'
# Renamed 'Seyoum et al. 1999.pdf' to '355.pdf'
# Renamed '23386Pirmatova-Screening for Gestational Diabetes M.pdf' to '23386.pdf'
# Renamed '15706Kragelund Niels-Gestational Diabetes Risk in M.pdf' to '15706.pdf'
# Renamed '22240.pdf' to '22240.pdf'
# Renamed '19652Lavery-Gestational diabetes in the United Stat.pdf' to '19652.pdf'
# Renamed 'Trends in maternal age and the relationship between advanced age and adverse pregnancy outcomes a population-based register study in Wuhan China 20102017.pdf' to '24016.pdf'
# Renamed '35914253.pdf' to '35914253.pdf'
# Renamed 'Dildy et al. 1996.pdf' to '1151.pdf'
# Renamed '18090.pdf' to '18090.pdf'
# Renamed '24908Pham-Plasma 25(OH)D Concentrations and Gestati.pdf' to '24908.pdf'
# Renamed 'Prevalence of 'Hyperglycemia in pregnancy' remained stable between 2006 and 2015 despite rise in conventional risk factors A hospital based study in Delhi North India..pdf' to '25310.pdf'
# Renamed 'je-30-208.pdf' to '16624.pdf'
# Renamed 'enm-2020-948.PMC8258326.pdf' to '25328.pdf'
# Renamed '12884_2019_Article_2632.pdf' to '15839.pdf'
# Renamed 'El Mallah et al. 1997.pdf' to '35914572.pdf'
# Renamed 'JDR2018-4679245.pdf' to '17419.pdf'
# Renamed 'Chia et al. 1996.pdf' to '1080.pdf'
# Renamed '20009.pdf' to '20009.pdf'
# Renamed '19376Sweeting-Baseline HbA1c to Identify High-Risk.pdf' to '19376.pdf'
# Renamed 'AJO-62-525.PMC9545300.pdf' to '23965.pdf'
# Renamed '41598_2020_Article_59065.pdf' to '20556.pdf'
# Renamed '26545Kragelund Niels-Migration Gestational Diabete.pdf' to '26545.pdf'
# Renamed '20183.pdf' to '20183.pdf'
# Renamed '21377Huidobro-[Association of abo blood groups with.pdf' to '21377.pdf'
# Renamed '15169.pdf' to '15169.pdf'
# Renamed 'aml-23-117.pdf' to '20230.pdf'
# Renamed '592_2019_Article_1404.pdf' to '16164.pdf'
# Renamed 'bmjopen-2018-026168.pdf' to '15564.pdf'
# Renamed 'Schwartz et al. 1999.pdf' to '415.pdf'
# Renamed '15299.pdf' to '15299.pdf'
# Renamed '12889_2021_Article_12000.pdf' to '24659.pdf'
# Renamed 'jcm-09-00582.pdf' to '15554.pdf'
# Renamed '12884_2020_Article_3284.pdf' to '14760.pdf'
# Renamed 'Naylor et al. 1996.pdf' to '1224.pdf'
# Renamed 'Joseph et al. 2005.pdf' to '10368.pdf'
# Renamed 'Tamez Perez et al. 1993.pdf' to '1815.pdf'
# Renamed '15727.pdf' to '15727.pdf'
# Renamed '35914553.pdf' to '35914553.pdf'
# Renamed 'Olagbuji et al. 2022.pdf' to '24306.pdf'
# Renamed '12884_2023_Article_5449.pdf' to '26316.pdf'
# Renamed 'Khine et al. 1999.pdf' to '183.pdf'
# Renamed '15666.pdf' to '15666.pdf'
# Renamed '12884_2019_Article_2374.pdf' to '16339.pdf'
# Renamed '25692Bashir-Screening pregnant women in a high-risk.pdf' to '25692.pdf'
# Renamed '24203Reitzle-Gestational diabetes in Germany_ Devel.pdf' to '24203.pdf'
# Renamed 'Moses and Griffiths 1995.pdf' to '1437.pdf'
# Renamed '35914408.pdf' to '35914408.pdf'
# Renamed 'Ramachandran et al. 1994.pdf' to '1632.pdf'
# Renamed '5624Surapaneni-Diagnostic effectiveness of 75g or.pdf' to '5624.pdf'
# Renamed 'MFP-17-43.pdf' to '22643.pdf'
# Renamed '19359.pdf' to '19359.pdf'
# Renamed 'bmjdrc-2021-002277.PMC8240580.pdf' to '25183.pdf'
# Renamed '16777Gortazar-Trends in prevalence of pre-existing.pdf' to '16777.pdf'
# Renamed 'Tarim et al. 2012.pdf' to '12347.pdf'
# Renamed 'je-33-127.pdf' to '25142.pdf'
# Renamed 'PJMS-35-325.pdf' to '16559.pdf'
# Renamed '41430_2018_Article_358.pdf' to '17227.pdf'
# Renamed 'pone.0153107.pdf' to '19997.pdf'
# Renamed '15030.pdf' to '15030.pdf'
# Renamed 'pone.0232664.pdf' to '15294.pdf'
# Renamed '18512Akgol-Prevalence of gestational diabetes melli.pdf' to '18512.pdf'
# Renamed '15322.pdf' to '15322.pdf'
# Renamed '17690.pdf' to '17690.pdf'
# Renamed 'Vitotoros et al. 1997.pdf' to '1049.pdf'
# Renamed 'AOGS-102-294.PMC9951355.pdf' to '22729.pdf'
# Renamed '16371Song-Recommended pre-analytical plasma glucose.pdf' to '16371.pdf'
# Renamed 'Ranchod et al. 1991.pdf' to '2191.pdf'
# Renamed 'Henry et al. 1993.pdf' to '1868.pdf'
# Renamed '20011.pdf' to '20011.pdf'
# Renamed 'Naylor et al. 1997.pdf' to '35914330.pdf'
# Renamed '40263_2022_Article_908.PMC9095513.pdf' to '24113.pdf'
# Renamed '24676Pavic-Prevalence of Gestational Diabetes Melli.pdf' to '24676.pdf'
# Renamed '13175Ricart-Body mass index has a greater impact on.pdf' to '13175.pdf'
# Renamed 'Roman et al. 2004.pdf' to '10590.pdf'
# Renamed 'Kim and Humphrey 1999.pdf' to '543.pdf'
# Renamed '21732.pdf' to '21732.pdf'
# Renamed '12966_2018_Article_701.pdf' to '17580.pdf'
# Renamed 'Zhang et al. 2019.pdf' to '17090.pdf'
# Renamed 'Siribaddana et al. 1998.pdf' to '35914625.pdf'
# Renamed '35914192.pdf' to '35914192.pdf'
# Renamed '21017.pdf' to '21017.pdf'
# Renamed 'Berkowitz et al. 1992.pdf' to '2039.pdf'
# Renamed '25480Aubry-Effect of the IADPSG screening strategy.pdf' to '25480.pdf'
# Renamed '12986_2020_Article_539.pdf' to '25906.pdf'
# Renamed 'Nduka et al. 1995.pdf' to '3809.pdf'
# Renamed 'pone.0247077.pdf' to '25791.pdf'
# Renamed '10222Kim-Changes in health status experienced by wo.pdf' to '10222.pdf'
# Renamed 'Effects of single and combined gestational phthalate exposure on blood pressure blood glucose and gestational weight gain A longitudinal analysis..pdf' to '25244.pdf'
# Renamed 'JFCM-23-94.PMC4859105.pdf' to '19888.pdf'
# Renamed 'nutrients-11-02822.pdf' to '15909.pdf'
# Renamed '15793Dickson-Fasting plasma glucose and risk factor.pdf' to '15793.pdf'
# Renamed '12954Montagnana-Glucose challenge test does not pre.pdf' to '12954.pdf'
# Renamed 'JDI-8-161.PMC5334332.pdf' to '19746.pdf'
# Renamed 'cureus-0015-00000035103.pdf' to '22320.pdf'
# Renamed 'nutrients-14-02145.pdf' to '26578.pdf'
# Renamed 'Zeki et al. 2019.pdf' to '16857.pdf'
# Renamed 'PAMJ-31-195.pdf' to '16557.pdf'
# Renamed 'PJMS-35-95.pdf' to '16760.pdf'
# Renamed '35914278.pdf' to '35914278.pdf'
# Renamed 'pone.0264992.pdf' to '26528.pdf'
# Renamed '19275Facco-Association Between Sleep-Disordered Bre.pdf' to '19275.pdf'
# Renamed 'Khan et al. 1991.pdf' to '2264.pdf'
# Renamed 'Buresi et al. 2010.pdf' to '21176301.pdf'
# Renamed '18972Hanna-Diagnosing gestational diabetes mellitus.pdf' to '18972.pdf'
# Renamed '12884_2015_Article_682.pdf' to '13955.pdf'
# Renamed 'bmjopen-2019-033296.PMC7045252.pdf' to '15637.pdf'
# Renamed 'Whitaker et al. 1998.pdf' to '35914329.pdf'
# Renamed 'PJMS-37-1625.pdf' to '24640.pdf'
# Renamed '23671Chelu-Prevalence of Gestational Diabetes in pr.pdf' to '23671.pdf'
# Renamed 'nutrients-08-00574.pdf' to '19506.pdf'
# Renamed 'Biodun et al. 2015.pdf' to '25855324.pdf'
# Renamed '22229Pedersen-Gestational diabetes mellitus in Gree.pdf' to '22229.pdf'
# Renamed '15899.pdf' to '15899.pdf'
# Renamed '9712.pdf' to '9712.pdf'
# Renamed '12940_2016_Article_194.pdf' to '19342.pdf'
# Renamed 'Ehrenthal et al. 2011.pdf' to '7591.pdf'
# Renamed 'Phillipou 1991.pdf' to '2151.pdf'
# Renamed 'JDR2016-8905474.pdf' to '19162.pdf'
# Renamed '19657.pdf' to '19657.pdf'
# Renamed 'Reinders et al. 2020.pdf' to '14740.pdf'
# Renamed '16523.pdf' to '16523.pdf'
# Renamed '20072Hantoushzadeh-The impact of gestational weight.pdf' to '20072.pdf'
# Renamed '21431Schoenaker-Association Between Age at Menarche.pdf' to '21431.pdf'
# Renamed '16792.pdf' to '16792.pdf'
# Renamed 'ijwh-8-035.PMC4734826.pdf' to '20135.pdf'
# Renamed 'pone.0178150.pdf' to '18814.pdf'
# Renamed '13148_2019_Article_687.pdf' to '16402.pdf'
# Renamed 'Nguyen et al. 2019.pdf' to '17217.pdf'
# Renamed 'jcm-11-06713.pdf' to '22813.pdf'
# Renamed '35914639.pdf' to '35914639.pdf'
# Renamed 'main.PMC9432018.pdf' to '15952.pdf'
# Renamed 'Deerochanawong et al. 1996.pdf' to '35914338.pdf'
# Renamed 'Walker et al. 2023.pdf' to '27270.pdf'
# Renamed 'Barakat et al. 2010.pdf' to '35914570.pdf'
# Renamed 'Beischer et al. 1997.pdf' to '858.pdf'
# Renamed '18301.pdf' to '18301.pdf'
# Renamed '24584Molina-Vega-Impact of the Gestational Diabetes.pdf' to '24584.pdf'
# Renamed 'main.PMC8626796.pdf' to '24462.pdf'
# Renamed 'oncotarget-08-80679.pdf' to '21295.pdf'
# Renamed 'pone.0151311.pdf' to '21634.pdf'
# Renamed 'Griffin et al. 1999.pdf' to '315.pdf'
# Renamed 'Nasrat et al. 1996.pdf' to '1128.pdf'
# Renamed '12884_2019_Article_2415.pdf' to '16111.pdf'
# Renamed 'AOGS-102-33.PMC9780714.pdf' to '26441.pdf'
# Renamed '22616.pdf' to '22616.pdf'
# Renamed 'Wendland et al. 2007.pdf' to '13047.pdf'
# Renamed 'cm9-133-269.PMC7004606.pdf' to '20709.pdf'
# Renamed 'pone.0276824.pdf' to '22821.pdf'
# Renamed '12884_2019_Article_2646.pdf' to '15857.pdf'
# Renamed '22643Abd Latif-The prevalence of gestational diabet.pdf' to '22643.pdf'
# Renamed 'Lao et al. 2012.pdf' to '6611.pdf'
# Renamed '1488Koukkou-Difference in prevalence of gestationa.pdf' to '1488.pdf'
# Renamed '16444.pdf' to '16444.pdf'
# Renamed '19642.pdf' to '19642.pdf'
# Renamed 'Wei et al. 2015_1.pdf' to '13746.pdf'
# Renamed 'pone.0277654.pdf' to '22728.pdf'
# Renamed 'main.pdf' to '22984.pdf'
# Renamed 'ACTA-89-11.PMC6179089.pdf' to '17531.pdf'
# Renamed 'pone.0243192.pdf' to '14526.pdf'
# Renamed '13920Kgosidialwa-Treatment With Diet and Exercise f.pdf' to '13920.pdf'
# Renamed '35914465.pdf' to '35914465.pdf'
# Renamed 'Goldzieher 1994.pdf' to '35914351.pdf'
# Renamed '24514Chodick-Adolescent body mass index and changes.pdf' to '24514.pdf'
# Renamed 'Shemer et al. 2013.pdf' to '23418899.pdf'
# Renamed 'Koivunen et al. 2015.pdf' to '14089.pdf'
# Renamed 'Khurseed et al. 2022.pdf' to '27168.pdf'
# Renamed '12884_2018_Article_1925.pdf' to '17605.pdf'
# Renamed '13104_2017_Article_2493.pdf' to '18871.pdf'
# Renamed 'ijerph-18-00560.pdf' to '25927.pdf'
# Renamed '19981.pdf' to '19981.pdf'
# Renamed 'Forest et al. 1994.pdf' to '1627.pdf'
# Renamed '21761.pdf' to '21761.pdf'
# Renamed '21105.pdf' to '21105.pdf'
# Renamed '4243Lynch-Increasing prevalence of diabetes during.pdf' to '4243.pdf'
# Renamed '17393.pdf' to '17393.pdf'
# Renamed 'Al-Turki et al. 2003.pdf' to '10920.pdf'
# Renamed '20135Ali-Impact of Recurrent Miscarriage on Materna.pdf' to '20135.pdf'
# Renamed '13039_2019_Article_451.pdf' to '16174.pdf'
# Renamed 'Ostlund et al. 2004.pdf' to '10819.pdf'
# Renamed '16559Abualhamael-Prevalence and Associated Risk Fac.pdf' to '16559.pdf'
# Renamed '23192Hanson-Screening of Gestational Diabetes and I.pdf' to '23192.pdf'
# Renamed 'Nerenberg et al. 2012.pdf' to '6550.pdf'
# Renamed 'medi-97-e0604.pdf' to '17823.pdf'
# Renamed '24630.pdf' to '24630.pdf'
# Renamed 'JFRH-15-53.PMC8346736.pdf' to '24918.pdf'
# Renamed '19057Pang-Higher Maternal Dietary Protein Intake Is.pdf' to '19057.pdf'
# Renamed 'pone.0229496.pdf' to '15515.pdf'
# Renamed 'JDR2022-8946971.pdf' to '26587.pdf'
# Renamed 'Wen et al. 2000.pdf' to '101.pdf'
# Renamed '23804Lendoye-Prevalence and factors associated to g.pdf' to '23804.pdf'
# Renamed 'Walker et al. 2020.pdf' to '17465.pdf'
# Renamed '19434.pdf' to '19434.pdf'
# Renamed 'bmjnph-2020-000149.PMC8258095.pdf' to '25061.pdf'
# Renamed '19654.pdf' to '19654.pdf'
# Renamed '35914532.pdf' to '35914532.pdf'
# Renamed '24598Bayoumi-Utility of oral glucose tolerance test.pdf' to '24598.pdf'
# Renamed '41598_2019_Article_52509.pdf' to '15965.pdf'
# Renamed '17472.pdf' to '17472.pdf'
# Renamed 'FVVinObGyn-9-133.pdf' to '18015.pdf'
# Renamed '8021.pdf' to '8021.pdf'
# Renamed 'Bonomo et al. 1998.pdf' to '671.pdf'
# Done
